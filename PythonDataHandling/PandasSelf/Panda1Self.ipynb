# %%
pip install cassandra-driver
# Out:
# ...
#   Created wheel for cassandra-driver: filename=cassandra_driver-3.25.0-cp39-cp39-win_amd64.whl size=2974336 sha256=0bbb4da045071b3af4da0f1e8024e45a3c81ff09142e0a60e0dabe38158a49a6
#   Stored in directory: c:\users\win\appdata\local\pip\cache\wheels\3d\bd\75\12875d7c70c5b18e8738c9e06f2d3f5b752fa372917c663fcc
# Successfully built cassandra-driver
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.read_csv("Sample_PD.CSV")
# Out:
#        name         emailId address  pincode surname
# 0  Abhishek  abhi@gmail.com   Delhi    13154   kumar
# 1      Sonu  sonu@gmail.com    Pune    21325   singh
# 2      Prem  prem@gmail.com  Mumbai    13156     jha

# %%
pd.read_csv(r'D:\Ineuron\DataSet\train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv(r"D:\Ineuron\DataSet\ohana-api-master\ohana-api-master\data\sample-csv\taxonomy.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv(r"D:\Ineuron\DataSet\carbon_nanotubes.csv", sep = ';')
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                    0,717298
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                    0,334292
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
pd.read_csv("Sample_PD.CSV", names = ['a', 'b', 'c', 'd', 'e'], header = None)
# Out:
#           a               b        c        d        e
# 0      name         emailId  address  pincode  surname
# 1  Abhishek  abhi@gmail.com    Delhi    13154    kumar
# 2      Sonu  sonu@gmail.com     Pune    21325    singh
# 3      Prem  prem@gmail.com   Mumbai    13156      jha

# %%
pd.read_csv("Sample_PD.CSV", header = None)
# Out:
#           0               1        2        3        4
# 0      name         emailId  address  pincode  surname
# 1  Abhishek  abhi@gmail.com    Delhi    13154    kumar
# 2      Sonu  sonu@gmail.com     Pune    21325    singh
# 3      Prem  prem@gmail.com   Mumbai    13156      jha

# %%
df1 = pd.read_csv("Sample_PD.CSV", header = None, skiprows = [0])

# %%
df1.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3     int64
# 4    object
# dtype: object

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['taxonomy_id', 'name', 'parent_id', 'parent_name'], dtype='object')

# %%
a = df['name']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a
# Out:
# 0                         Emergency
# 1                 Disaster Response
# 2                    Emergency Cash
# 3                 Help Pay for Food
# 4           Help Pay for Healthcare
#                    ...
# 285                Workplace Rights
# 286                       Mediation
# 287                          Notary
# 288                  Representation
# 289    Translation & Interpretation
# Name: name, Length: 290, dtype: object

# %%
df['name', 'parent_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'parent_id')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
b = df[['name', 'parent_id']]

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel(r'C:\Users\win\Downloads\ExcelExamples-master\ExcelExamples-master/Cell Phone Plans compared.xlsx')
# Out:
#         Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0              NaN        Dog        Cat
# 1          Initial        NaN        NaN
# 2         Purchase        NaN        NaN
# 3           Collar        NaN        NaN
# 4              Tag        NaN        NaN
# 5             Bowl        NaN        NaN
# 6            Leash        NaN        NaN
# 7      Intial Toal        NaN        NaN
# 8              NaN        NaN        NaN
# 9          Monthly        NaN        NaN
# 10            Food        NaN        NaN
# 11          Litter        NaN        NaN
# 12          Treats        NaN        NaN
# 13        Subtotal        NaN        NaN
# 14   Monthly Total        NaN        NaN
# 15             NaN        Dog        Cat
# 16  One Year Costs          0          0

# %%
df = pd.ExcelFile(r'C:\Users\win\Downloads\ExcelExamples-master\ExcelExamples-master/Cell Phone Plans compared.xlsx')

# %%
df.sheet_names
# Out:
# ['Cat or Dog (2)',
#  'school supplies (2)',
#  'school supplies',
#  'Cat or Dog',
#  'vacations',
#  'Printers',
#  'cell phones',
#  'cars']

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
