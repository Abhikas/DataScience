# %%
mongodb+srv://mongodb:<password>@cluster0.3si7z.mongodb.net/myFirstDatabase?retryWrites=true&w=majority

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://mongodb:mongodb@cluster0.3si7z.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.3si7z.mongodb.net:27017', 'cluster0-shard-00-02.3si7z.mongodb.net:27017', 'cluster0-shard-00-00.3si7z.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-cry1vz-shard-0', tls=True), 'test')

# %%
pip install pymongo[srv]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
client.list_database_names()
# Out:
# ['admin', 'local']

# %%
db2 = client["Abhi"]

# %%
coll1 = db2['ineuron_collection']

# %%
dict1 = {
    "name": "Abhishek",
    "email": "abhi@gmail.com",
    "product":["oneneuron", "techneuron"]
}

# %%
coll1.insert_one(dict1)

# %%
list1 = [
    {
    "name": "Abhishek",
    "email": "abhi@gmail.com",
    "product":["oneneuron", "techneuron"]
},
{
    "name": "Kumar",
    "email": "Kumar@gmail.com",
    "product":["oneneuron", "techneuron"]
},
    {
    "name": "Babloo",
    "email": "abhi@gmail.com",
    "product":["oneneuron", "techneuron"]
}
]

# %%
coll1.insert_many(list1)

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('62089b80c1201797f648520c'), 'name': 'AbhKumarAbhishekek', 'email': 'abhi@gmail.com', 'product': ['oneneuron', 'techneuron']}
# {'_id': ObjectId('62089f41c1201797f648520d'), 'name': 'Abhishek', 'email': 'abhi@gmail.com', 'product': ['oneneuron', 'techneuron']}
# {'_id': ObjectId('62089f41c1201797f648520e'), 'name': 'Kumar', 'email': 'Kumar@gmail.com', 'product': ['oneneuron', 'techneuron']}
# {'_id': ObjectId('62089f41c1201797f648520f'), 'name': 'Babloo', 'email': 'abhi@gmail.com', 'product': ['oneneuron', 'techneuron']}

# %%
for i in coll1.find({"name": "Abhishek"}):
    print(i)
# Out:
# {'_id': ObjectId('62089f41c1201797f648520d'), 'name': 'Abhishek', 'email': 'abhi@gmail.com', 'product': ['oneneuron', 'techneuron']}

# %%
import csv
import json

# %%
csv_FilePath = r'Sample_pd.csv'
data = {}

# %%
with open(csv_FilePath) as f:
    csvReader = csv.DictReader(f)
    key = 0
    for rows in csvReader:
            data[key] = rows
            key = key+1

# %%
data
# Out:
# {0: {'name': 'Abhishek',
#   'emailId': 'abhi@gmail.com',
#   'address': 'Delhi',
#   'pincode': '13154',
#   'surname': 'kumar'},
#  1: {'name': 'Sonu',
#   'emailId': 'sonu@gmail.com',
#   'address': 'Pune',
#   'pincode': '21325',
#   'surname': 'singh'},
#  2: {'name': 'Prem',
#   'emailId': 'prem@gmail.com',
#   'address': 'Mumbai',
#   'pincode': '13156',
#   'surname': 'jha'}}

# %%
list1 = []
with open(csv_FilePath) as f:
    csvReader = csv.DictReader(f)
    key = 0
    for rows in csvReader:
            list1.append(rows)

# %%
list1
# Out:
# [{'name': 'Abhishek',
#   'emailId': 'abhi@gmail.com',
#   'address': 'Delhi',
#   'pincode': '13154',
#   'surname': 'kumar'},
#  {'name': 'Sonu',
#   'emailId': 'sonu@gmail.com',
#   'address': 'Pune',
#   'pincode': '21325',
#   'surname': 'singh'},
#  {'name': 'Prem',
#   'emailId': 'prem@gmail.com',
#   'address': 'Mumbai',
#   'pincode': '13156',
#   'surname': 'jha'}]

# %%
csv_FilePath1 = r'D:\Ineuron\DataSet\carbon_nanotubes.csv'

# %%
list2 = []
with open(csv_FilePath1) as f:
    csvReader = csv.DictReader(f)
    key = 0
    for rows in csvReader:
            list2.append(rows)

# %%
list2
# Out:
# [{"Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'": '2;1;0',
#   None: ['679005;0',
#    '701318;0',
#    '017033;0',
#    '721039;0',
#    '730232;0',
#    '017014']},
#  {"Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'": '2;1;0',
#   None: ['717298;0', '642129;0', '231319;0', '738414;0', '65675;0', '232369']},
#  {"Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'": '2;1;0',
#   None: ['489336;0',
#    '303751;0',
#    '088462;0',
#    '477676;0',
#    '263221;0',
#    '088712']},
# ...

# %%
str1 = "abbbacd"

# %%
str1.replace('a', 'k')
# Out:
# 'kbbbkcd'

# %%
with open(csv_FilePath1, 'r') as f:
    csvReader = csv.reader(f, delimiter = '\n')
    
for row in csvReader:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/538991531.py in <module>
#       2     csvReader = csv.reader(f, delimiter = '\n')
#       3
# ----> 4 for row in csvReader:
#       5     print(row)
#
# ValueError: I/O operation on closed file.

# %%
with open(csv_FilePath1, 'r') as f:
    csvReader = csv.reader(f, delimiter = '\n')
    for row in csvReader:
        print(type(row))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ...

# %%
for row in csvReader:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/673442518.py in <module>
# ----> 1 for row in csvReader:
#       2     print(row)
#
# ValueError: I/O operation on closed file.
